# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# 1. df Exploration and Understanding:

# %%
# Import necessary libraries
import pandas as pd

# Load the dfset
df = pd.read_csv('WHR-2024-5CS037.csv')

# Display the first few rows
df.head()

# Get basic information about the dfset
df.info()

# Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   score                         143 non-null    float64
#  2   Log GDP per capita            140 non-null    float64
#  3   Social support                140 non-null    float64
#  4   Healthy life expectancy       140 non-null    float64
#  5   Freedom to make life choices  140 non-null    float64
#  6   Generosity                    140 non-null    float64
#  7   Perceptions of corruption     140 non-null    float64
#  8   Dystopia + residual           140 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 10.2+ KB
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# ...

# %%
#2 Identify the number of rows and columns in the dfset.
print(df.shape)
# Out:
# (143, 9)

# %%
#3 List all the columns and their df types.
print(df.dtypes)
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %%
# Basic Statistics
#1 Calculate the mean, median, and standard deviation for the Score column.
print(df['score'].mean())
print(df['score'].median())
print(df['score'].std())
# Out:
# 5.52758041958042
# 5.785
# 1.1707165099442993

# %%
#2 Identify the country with the highest and lowest happiness scores.
print(df.loc[df['score'].idxmax()])
print(df.loc[df['score'].idxmin()])
# Out:
# Country name                    Finland
# score                             7.741
# Log GDP per capita                1.844
# Social support                    1.572
# Healthy life expectancy           0.695
# Freedom to make life choices      0.859
# Generosity                        0.142
# Perceptions of corruption         0.546
# Dystopia + residual               2.082
# Name: 0, dtype: object
# Country name                    Afghanistan
# score                                 1.721
# Log GDP per capita                    0.628
# Social support                          0.0
# Healthy life expectancy               0.242
# Freedom to make life choices            0.0
# Generosity                            0.091
# Perceptions of corruption             0.088
# Dystopia + residual                   0.672
# Name: 142, dtype: object

# %%
#Missing Values:
#1  Check if there are any missing values in the dfset. If so, display the total count for each column.
print(df.isnull().sum())
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %%
# Filtering and Sorting:
#1 Filter the dfset to show only the countries with a Score greater than 7.5.
filtered_data_scoredf= df[df['score'] > 7.5]
filtered_data_scoredf
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
#2 For the filtered dfset - Sort the dfset by GDP per Capita in descending order and display the top 10 rows.
filtered_data_scoredf = filtered_data_scoredf.sort_values(by='Log GDP per capita', ascending=False)
filtered_data_scoredf.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %%
#Adding New Columns:
#1. Create a new column called Happiness Category that categorizes countries into three categories based on their Score:
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

df['Happiness Category'] = np.where(df['score'] < 4, 'Low', np.where(df['score'] <= 6, 'Medium', 'High'))
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2. df Visualizations:

# %%
#Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
top10Countries = df.sort_values(by='score', ascending=False).head(10)
top10Countries.plot(x='Country name', y='score', kind='bar', title='Top 10 Happiest Countries by Score')
plt.show()

# %%
# Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
top10UnhappiestCountries = df.sort_values(by='score', ascending=True).head(10)
top10UnhappiestCountries.plot(x='Country name', y='score', kind='line', title='Top 10 Unhappiest Countries by Score')
plt.show()

# %%
#Plot a histogram for the Score column to show its distribution and also interpret.
df['score'].plot(kind='hist', title='Distribution of Score',xlabel='Score', ylabel='Frequency', edgecolor = 'black')
plt.show()

# %%
#Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.
df.plot(x='Log GDP per capita',xlabel="GDP per capita", y='score', kind='scatter', title='GDP per Capita vs Score')
plt.show()

# %% [markdown]
# Some Advance df Exploration Task:
#
# 1. Preparing the South-Asia dfset:

# %%
# List of South Asian countries
south_asian_countries = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# Filter South Asian countries
south_asia_df = df[df['Country name'].isin(south_asian_countries)]
print(south_asia_df[['Country name', 'score']].sort_values(by='score', ascending=False))

south_asia_df.to_csv('south_asian_countries.csv', index=False)
# Out:
#     Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054
# 127    Sri Lanka  3.898
# 128   Bangladesh  3.886
# 142  Afghanistan  1.721

# %% [markdown]
# 2. Composite Score Ranking:

# %%
# 1. Using the SouthAsia dfFrame, create a new column called Composite Score that combines the following metrics: Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support + 0.30 × Healthy Life Expectancy

south_asia_df = pd.read_csv('south_asian_countries.csv')
south_asia_df['Composite Score'] = 0.40 * south_asia_df['Log GDP per capita'] + 0.30 * south_asia_df['Social support'] + 0.30 * south_asia_df['Healthy life expectancy']
# 2. Rank the South Asian countries based on the Composite Score in descending order.
south_asia_df = south_asia_df.sort_values(by='Composite Score', ascending=False)
print(south_asia_df[['Country name', 'Composite Score']])
# Out:
#   Country name  Composite Score
# 3    Sri Lanka           1.0739
# 0        Nepal           0.8159
# 2        India           0.7874
# 1     Pakistan           0.7039
# 4   Bangladesh           0.6774
# 5  Afghanistan           0.3238

# %%
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
top5Countries = south_asia_df.head(5)
top5Countries.plot(x='Country name', y='Composite Score', kind='barh', title='Top 5 South Asian Countries by Composite Score')
plt.show()

# %%
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your discussion with some visualization plot.
south_asia_df['Rank'] = south_asia_df['Composite Score'].rank(ascending=False)
south_asia_df['Original Rank'] = south_asia_df['score'].rank(ascending=False)
south_asia_df.plot(x='Country name', y=['Rank', 'Original Rank'], kind='bar', title='Rankings based on Composite Score vs Original Score')
plt.show()

# %% [markdown]
# 3. Outlier Detection

# %%
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.
score_iqr = south_asia_df['score'].quantile(0.75) - south_asia_df['score'].quantile(0.25)
gdp_iqr = south_asia_df['Log GDP per capita'].quantile(0.75) - south_asia_df['Log GDP per capita'].quantile(0.25)

# Determine the lower and upper bounds for outliers
score_lower_bound = south_asia_df['score'].quantile(0.25) - 1.5 * score_iqr
score_upper_bound = south_asia_df['score'].quantile(0.75) + 1.5 * score_iqr
gdp_lower_bound = south_asia_df['Log GDP per capita'].quantile(0.25) - 1.5 * gdp_iqr
gdp_upper_bound = south_asia_df['Log GDP per capita'].quantile(0.75) + 1.5 * gdp_iqr

# Identify outliers
outliers = south_asia_df[
    (south_asia_df['score'] < score_lower_bound) | (south_asia_df['score'] > score_upper_bound) |
    (south_asia_df['Log GDP per capita'] < gdp_lower_bound) | (south_asia_df['Log GDP per capita'] > gdp_upper_bound)
]

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(south_asia_df['Log GDP per capita'], south_asia_df['score'], label='Normal')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], color='red', label='Outliers')
plt.xlabel(' GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter Plot of  GDP per Capita vs Score in South Asia')
plt.legend()
plt.show()

# %% [markdown]
# 4. Exploring Trends Across Metrics:

# %%
#1 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation {pearson correlation} with the Score for South Asian countries.

# Filter df for South Asia region
south_asia_df = pd.read_csv('south_asian_countries.csv')

# Metrics to analyze
metrics = ['Freedom to make life choices', 'Generosity']

# Calculate Pearson correlation
correlations = {}
for metric in metrics:
    correlation = south_asia_df['score'].corr(south_asia_df[metric])
    correlations[metric] = correlation

print("Pearson Correlation with Happiness Score for South Asian Countries:")
for metric, corr in correlations.items():
    print(f"{metric}: {corr:.2f}")
# Out:
# Pearson Correlation with Happiness Score for South Asian Countries:
# Freedom to make life choices: 0.80
# Generosity: 0.87

# %%
# Create scatter plots with trendlines for these metrics against the Score
# Scatter Plot for Freedom to Make Life Choices vs Score
plt.figure(figsize=(8, 6))
plt.scatter(south_asia_df['Freedom to make life choices'], south_asia_df['score'], color='blue', s=50)
m, b = np.polyfit(south_asia_df['Freedom to make life choices'], south_asia_df['score'], 1)
plt.plot(south_asia_df['Freedom to make life choices'], m*south_asia_df['Freedom to make life choices'] + b, color='red')
plt.title('Freedom to Make Life Choices vs Happiness Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Happiness Score')
plt.grid(True)
plt.show()

# Scatter Plot for Generosity vs Score
plt.figure(figsize=(8, 6))
plt.scatter(south_asia_df['Generosity'], south_asia_df['score'], color='green', s=50)
m, b = np.polyfit(south_asia_df['Generosity'], south_asia_df['score'], 1)
plt.plot(south_asia_df['Generosity'], m*south_asia_df['Generosity'] + b, color='red')
plt.title('Generosity vs Happiness Score')
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.grid(True)
plt.show()

# %% [markdown]
# 5.  Gap Analysis:

# %%
#1 Add a new column for GDP-Score Gap

south_asia_df['GDP-Score Gap'] = south_asia_df['Log GDP per capita'] - south_asia_df['score']
print("\nSouth Asian countries with GDP-Score Gap:")
print(south_asia_df[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])
# Out:
# South Asian countries with GDP-Score Gap:
#   Country name  Log GDP per capita  score  GDP-Score Gap
# 0        Nepal               0.965  5.158         -4.193
# 1     Pakistan               1.069  4.657         -3.588
# 2        India               1.166  4.054         -2.888
# 3    Sri Lanka               1.361  3.898         -2.537
# 4   Bangladesh               1.122  3.886         -2.764
# 5  Afghanistan               0.628  1.721         -1.093

# %%
#2
ascending_gap = south_asia_df.sort_values(by='GDP-Score Gap', ascending=True)
descending_gap = south_asia_df.sort_values(by='GDP-Score Gap', ascending=False)

print("\nTop 3 countries with the largest positive GDP-Score Gaps:")
print(descending_gap[['Country name', 'GDP-Score Gap']].head(3))

print("\nTop 3 countries with the largest negative GDP-Score Gaps:")
print(ascending_gap[['Country name', 'GDP-Score Gap']].head(3))
# Out:
# Top 3 countries with the largest positive GDP-Score Gaps:
#   Country name  GDP-Score Gap
# 5  Afghanistan         -1.093
# 3    Sri Lanka         -2.537
# 4   Bangladesh         -2.764
#
# Top 3 countries with the largest negative GDP-Score Gaps:
#   Country name  GDP-Score Gap
# 0        Nepal         -4.193
# 1     Pakistan         -3.588
# 2        India         -2.888

# %%
#3  Highlight top 3 positive and negative gaps using a bar chart using pandas.
import pandas as pd
import matplotlib.pyplot as plt

# Select top 3 positive and negative gaps
top_positive_gaps = descending_gap.head(3)
top_negative_gaps = ascending_gap.head(3)

# Combine positive and negative gaps
combined_gaps = pd.concat([top_positive_gaps, top_negative_gaps])

# Sort by GDP-Score gap for better visualization
combined_gaps = combined_gaps.sort_values(by="GDP-Score Gap", ascending=False)

# Plotting
plt.figure(figsize=(10, 6))

# Assign colors: Blue for positive, Red for negative
colors = ['blue' if gap > 0 else 'red' for gap in combined_gaps['GDP-Score Gap']]

# Create a horizontal bar chart
plt.barh(combined_gaps['Country name'], combined_gaps['GDP-Score Gap'], color=colors)

# Add a vertical line at x=0 to separate positive and negative gaps
plt.axvline(0, color='black', linestyle='--', linewidth=0.8)

# Add titles and labels
plt.title('Top 3 Positive and Negative GDP-Score Gaps in South Asia')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')

# Adjust layout for better fit
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# Comparative Analysis:

# %%
#  Preparing the Middle Eastern dfset:
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
"Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]
middle_east_df = df[df['Country name'].isin(middle_east_countries)]
middle_east_df

middle_east_df.to_csv('middle_east_countries.csv', index=False)

# %%
#1  Descriptive Statistics
# Calculate mean and standard deviation of Scores for both regions
south_asia_mean = south_asia_df['score'].mean()
south_asia_std = south_asia_df['score'].std()
middle_east_mean = middle_east_df['score'].mean()
middle_east_std = middle_east_df['score'].std()

print("\nDescriptive Statistics for Happiness Score:")
print(f"South Asia - Mean: {south_asia_mean:.2f}, Std Dev: {south_asia_std:.2f}")
print(f"Middle East - Mean: {middle_east_mean:.2f}, Std Dev: {middle_east_std:.2f}")

# Compare averages
if south_asia_mean > middle_east_mean:
    print("South Asia has higher average happiness scores.")
else:
    print("Middle East has higher average happiness scores.")
# Out:
# Descriptive Statistics for Happiness Score:
# South Asia - Mean: 3.90, Std Dev: 1.18
# Middle East - Mean: 5.41, Std Dev: 1.57
# Middle East has higher average happiness scores.

# %%
#2 Top and Bottom Performers
# Top and bottom performers in each region
top_south_asia = south_asia_df.nlargest(3, 'score')
bottom_south_asia = south_asia_df.nsmallest(3, 'score')

top_middle_east = middle_east_df.nlargest(3, 'score')
bottom_middle_east = middle_east_df.nsmallest(3, 'score')

print("\nTop and Bottom Performers:")
print("South Asia - Top 3:")
print(top_south_asia[['Country name', 'score']])
print("South Asia - Bottom 3:")
print(bottom_south_asia[['Country name', 'score']])

print("Middle East - Top 3:")
print(top_middle_east[['Country name', 'score']])
print("Middle East - Bottom 3:")
print(bottom_middle_east[['Country name', 'score']])

# Plot bar charts
plt.figure(figsize=(12, 6))
plt.bar(top_south_asia['Country name'], top_south_asia['score'], label='South Asia', alpha=0.7)
plt.bar(top_middle_east['Country name'], top_middle_east['score'], label='Middle East', alpha=0.7)
plt.title('Top Performers in South Asia vs Middle East')
plt.xlabel('Country name')
plt.ylabel('Happiness Score')
plt.legend()
plt.show()
# Out:
# Top and Bottom Performers:
# South Asia - Top 3:
#   Country name  score
# 0        Nepal  5.158
# 1     Pakistan  4.657
# 2        India  4.054
# South Asia - Bottom 3:
#   Country name  score
# 5  Afghanistan  1.721
# 4   Bangladesh  3.886
# 3    Sri Lanka  3.898
# Middle East - Top 3:
#             Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733
# Middle East - Bottom 3:
#     Country name  score
# 141      Lebanon  2.707
# 132        Yemen  3.561
# 124       Jordan  4.186

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset (replace 'middle_east_countries.csv' with the actual filename)
south_asia_df = pd.read_csv('south_asian_countries.csv')
middle_east_df = pd.read_csv('middle_east_countries.csv')

# Metrics to compare
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']

# Calculate means for both groups
sa_metrics_mean = south_asia_df[metrics].mean()
me_metrics_mean = middle_east_df[metrics].mean()

# Grouped bar chart
metric_df = pd.DataFrame({'South Asia': sa_metrics_mean, 'Middle East': me_metrics_mean})
metric_df.plot(kind='bar', figsize=(10, 6))

# Customize the plot
plt.title('Key Metrics Comparison: South Asia vs Middle East')
plt.xlabel('Metrics')
plt.ylabel('Average Value')
plt.legend(title="Regions")
plt.tight_layout()
plt.show()

# Identify largest disparity
disparity = abs(sa_metrics_mean - me_metrics_mean)
print("\nMetrics Disparity:")
print(disparity)
largest_disparity_metric = disparity.idxmax()
print(f"Largest Disparity: {largest_disparity_metric} ({disparity[largest_disparity_metric]:.2f})")
# Out:
# Metrics Disparity:
# Log GDP per capita         0.444500
# Social support             0.540944
# Healthy life expectancy    0.133778
# dtype: float64
# Largest Disparity: Social support (0.54)

# %%
#4 Happiness Disparity
# Compute range and coefficient of variation
sa_range = south_asia_df['score'].max() - south_asia_df['score'].min()
me_range = middle_east_df['score'].max() - middle_east_df['score'].min()

sa_cv = south_asia_df['score'].std() / south_asia_df['score'].mean()
me_cv = middle_east_df['score'].std() / middle_east_df['score'].mean()

print("\nHappiness Disparity:")
print(f"South Asia - Range: {sa_range:.2f}, Coefficient of Variation: {sa_cv:.2f}")
print(f"Middle East - Range: {me_range:.2f}, Coefficient of Variation: {me_cv:.2f}")

if sa_cv > me_cv:
    print("South Asia has greater variability in happiness.")
else:
    print("Middle East has greater variability in happiness.")
# Out:
# Happiness Disparity:
# South Asia - Range: 3.44, Coefficient of Variation: 0.30
# Middle East - Range: 4.63, Coefficient of Variation: 0.29
# South Asia has greater variability in happiness.

# %%
# 4 Correlation Analysis
# Correlation for both regions
sa_corr = south_asia_df[['score', 'Freedom to make life choices', 'Generosity']].corr()
me_corr = middle_east_df[['score', 'Freedom to make life choices', 'Generosity']].corr()

print("\nCorrelation Analysis (South Asia):")
print(sa_corr)
print("\nCorrelation Analysis (Middle East):")
print(me_corr)



# Scatter plots
sns.lmplot(x='Freedom to make life choices', y='score', data=south_asia_df)
plt.title('South Asia: Freedom to make life choices vs Happiness Score')
plt.show()

sns.lmplot(x='Freedom to make life choices', y='score', data=middle_east_df)
plt.title('Middle East: Freedom to make life choices vs Happiness Score')
plt.show()
# Out:
# Correlation Analysis (South Asia):
#                                  score  Freedom to make life choices  \
# score                         1.000000                      0.800519
# Freedom to make life choices  0.800519                      1.000000
# Generosity                    0.874512                      0.733396
#
#                               Generosity
# score                           0.874512
# Freedom to make life choices    0.733396
# Generosity                      1.000000
#
# Correlation Analysis (Middle East):
#                                  score  Freedom to make life choices  \
# score                         1.000000                      0.863220
# Freedom to make life choices  0.863220                      1.000000
# Generosity                    0.627524                      0.388854
#
#                               Generosity
# score                           0.627524
# Freedom to make life choices    0.388854
# Generosity                      1.000000

# %%
# Define the outlier detection function
def detect_outliers(df, column):
    """
    Detect outliers in a specified column using the IQR method.

    Parameters:
        df (pd.dfFrame): The dfset containing the column to analyze.
        column (str): The name of the column for which to detect outliers.

    Returns:
        pd.dfFrame: A dfFrame containing rows identified as outliers.
    """
    # Calculate IQR
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1

    # Calculate bounds for outliers
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Filter outliers
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]

    return outliers


# Detect outliers for South Asia and Middle East
score_sa_outliers = detect_outliers(south_asia_df, 'score')
gdp_sa_outliers = detect_outliers(south_asia_df, 'Log GDP per capita')
score_me_outliers = detect_outliers(middle_east_df, 'score')
gdp_me_outliers = detect_outliers(middle_east_df, 'Log GDP per capita')

# Combine outliers for South Asia
sa_outliers = pd.concat([score_sa_outliers, gdp_sa_outliers]).drop_duplicates()

# Combine outliers for Middle East
me_outliers = pd.concat([score_me_outliers, gdp_me_outliers]).drop_duplicates()

# Print outliers
print("\nOutliers in South Asia:")
print(sa_outliers[['Country name', 'score', 'Log GDP per capita']])

print("\nOutliers in Middle East:")
print(me_outliers[['Country name', 'score', 'Log GDP per capita']])

# Plot outliers
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_df, label='South Asia', color='blue', alpha=0.5)
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_df, label='Middle East', color='green', alpha=0.5)
sns.scatterplot(x='Log GDP per capita', y='score', data=sa_outliers, label='South Asia Outliers', color='red', s=100, marker='o')
sns.scatterplot(x='Log GDP per capita', y='score', data=me_outliers, label='Middle East Outliers', color='orange', s=100, marker='^')

plt.title('Outliers in South Asia and Middle East')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.legend()
plt.show()
# Out:
# Outliers in South Asia:
#   Country name  score  Log GDP per capita
# 5  Afghanistan  1.721               0.628
#
# Outliers in Middle East:
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita]
# Index: []

# %%
#7 Boxplot
# Boxplot for score distribution
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=pd.concat([south_asia_df.assign(Region='South Asia'), middle_east_df.assign(Region='Middle East')]))
plt.title('Distribution of Happiness Scores: South Asia vs Middle East')
plt.xlabel('Region')
plt.ylabel('Happiness Score')
plt.show()
